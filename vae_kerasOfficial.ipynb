# %% [markdown]
# <a href="https://colab.research.google.com/github/makkimaki/VAEprojects/blob/master/vae_kerasOfficial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Create a sampling layer

# %%
class Sampling(layers.Layer):
  """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""
  
  def call(self, inputs):
    """Sampling class

    Args: 
      input -- parameters of distribution

    Returns:
      latent variable 'z' with reparameterize trick
    """
    z_mean, z_log_var = inputs
    batch = tf.shape(z_mean)[0]
    dim = tf.shape(z_mean)[1]
    epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# ## Build the encoder

# %% [markdown]
# ### Encoder ver1-1.

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))  #ここをtf.keras.で定義しないと，後のcompile時もtf.keras.optimizers.Adam()は使えない？？
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)

z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 14, 14, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 64)     18496       conv2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           50192       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            34          dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            34          dense[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 2)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 69,076
# Trainable params: 69,076
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Encoder ver1-2.

# %%
# latent_dim = 8

# encoder1_2 = tf.keras.Sequential(
#     [
#      tf.keras.layers.InputLayer(input_shape=(28,28,1)),
#      tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=2, activation="relu"),
#      tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=2, activation="relu"),
#      tf.keras.layers.Flatten(),
#      tf.keras.layers.Dense(latent_dim * 2)
#     ]
# )

# %% [markdown]
# ## Build the decoder

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)

decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 32)        18464
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 1)         289
# =================================================================
# Total params: 65,089
# Trainable params: 65,089
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define the VAE as a Model with a custom train_step

# %%
class VAE(tf.keras.Model):
  def __init__(self, encoder, decoder, **kwargs):
    super(VAE, self).__init__(**kwargs)
    self.encoder = encoder
    self.decoder = decoder
  
  def train_step(self, data):
    if isinstance(data, tuple):
      data = data[0]
    with tf.GradientTape() as tape:
      z_mean, z_log_var, z = encoder(data)
      reconstruction = decoder(z)
      reconstruction_loss = tf.reduce_mean(
          keras.losses.binary_crossentropy(data, reconstruction)
      )
      reconstruction_loss *= 28 * 28
      kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
      kl_loss = tf.reduce_mean(kl_loss)
      kl_loss *= -1/2
      total_loss = reconstruction_loss + kl_loss
    grads = tape.gradient(total_loss, self.trainable_weights)
    self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
    return {
        "loss": total_loss,
        "reconstruction_loss": reconstruction_loss,
        "kl_loss": kl_loss,
    }

# %% [markdown]
# ## Train the VAE

# %%
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(mnist_digits, epochs=30, batch_size=128)

# (x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
# mnist_digits = np.concatenate([x_train, x_test], axis=0)
# mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

# vae = VAE(encoder, decoder)
# vae.compile(optimizer=keras.optimizers.Adam())
# vae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Epoch 1/30
# 547/547 [==============================] - 4s 7ms/step - loss: 144.4720 - reconstruction_loss: 140.8471 - kl_loss: 3.6249
# Epoch 2/30
# 547/547 [==============================] - 4s 7ms/step - loss: 144.3435 - reconstruction_loss: 140.7105 - kl_loss: 3.6330
# Epoch 3/30
# 547/547 [==============================] - 4s 7ms/step - loss: 144.2002 - reconstruction_loss: 140.5636 - kl_loss: 3.6367
# Epoch 4/30
# 547/547 [==============================] - 4s 7ms/step - loss: 144.1607 - reconstruction_loss: 140.5276 - kl_loss: 3.6331
# Epoch 5/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.9644 - reconstruction_loss: 140.3177 - kl_loss: 3.6467
# Epoch 6/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.9820 - reconstruction_loss: 140.3376 - kl_loss: 3.6444
# Epoch 7/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.8025 - reconstruction_loss: 140.1445 - kl_loss: 3.6580
# Epoch 8/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.7505 - reconstruction_loss: 140.0919 - kl_loss: 3.6586
# Epoch 9/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.6655 - reconstruction_loss: 140.0070 - kl_loss: 3.6585
# Epoch 10/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.5808 - reconstruction_loss: 139.9250 - kl_loss: 3.6559
# Epoch 11/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.4786 - reconstruction_loss: 139.8031 - kl_loss: 3.6755
# Epoch 12/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.4055 - reconstruction_loss: 139.7329 - kl_loss: 3.6726
# Epoch 13/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.3557 - reconstruction_loss: 139.6756 - kl_loss: 3.6801
# Epoch 14/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.2390 - reconstruction_loss: 139.5494 - kl_loss: 3.6896
# Epoch 15/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.1801 - reconstruction_loss: 139.4859 - kl_loss: 3.6942
# Epoch 16/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.1072 - reconstruction_loss: 139.4242 - kl_loss: 3.6830
# Epoch 17/30
# 547/547 [==============================] - 4s 7ms/step - loss: 143.1746 - reconstruction_loss: 139.4844 - kl_loss: 3.6902
# Epoch 18/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.9857 - reconstruction_loss: 139.2853 - kl_loss: 3.7004
# Epoch 19/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.9396 - reconstruction_loss: 139.2496 - kl_loss: 3.6899
# Epoch 20/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.8817 - reconstruction_loss: 139.1792 - kl_loss: 3.7025
# Epoch 21/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.7936 - reconstruction_loss: 139.0799 - kl_loss: 3.7137
# Epoch 22/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.8315 - reconstruction_loss: 139.1264 - kl_loss: 3.7051
# Epoch 23/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.6993 - reconstruction_loss: 138.9925 - kl_loss: 3.7067
# Epoch 24/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.6302 - reconstruction_loss: 138.9189 - kl_loss: 3.7113
# Epoch 25/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.5949 - reconstruction_loss: 138.8804 - kl_loss: 3.7145
# Epoch 26/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.5491 - reconstruction_loss: 138.8327 - kl_loss: 3.7164
# Epoch 27/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.4580 - reconstruction_loss: 138.7293 - kl_loss: 3.7287
# Epoch 28/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.4288 - reconstruction_loss: 138.7062 - kl_loss: 3.7226
# Epoch 29/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.3319 - reconstruction_loss: 138.5989 - kl_loss: 3.7330
# Epoch 30/30
# 547/547 [==============================] - 4s 7ms/step - loss: 142.3907 - reconstruction_loss: 138.6496 - kl_loss: 3.7411

# %% [markdown]
# ## Display a grid of sampled digits

# %%
import matplotlib.pyplot as plt

def plot_latent(encoder, decoder):
  """display a n*n 2D manifold of digits.

  Args: 
    tf.keras.Model: encoder and decoder

  Returns:
    plt.imshow()
  """
  n = 40
  digit_size = 28
  scale = 2.0
  figsize = 15
  figure = np.zeros((digit_size * n, digit_size * n))
  # linearly spaced coordinates corresponding to the 2D plot
  # of digit classes in the latent space
  grid_x = np.linspace(-scale, scale, n)
  grid_y = np.linspace(-scale, scale, n)[::-1]

  for i, yi in enumerate(grid_y):
    for j, xi in enumerate(grid_x):
      z_sample = np.array([[xi, yi]])
      x_decoded = decoder.predict(z_sample)
      digit = x_decoded[0].reshape(digit_size, digit_size)
      figure[
             i * digit_size : (i + 1) * digit_size,
             j * digit_size : (j + 1) * digit_size,
      ] = digit

  plt.figure(figsize=(figsize, figsize))
  start_range = digit_size // 2
  end_range = n * digit_size + start_range + 1
  pixel_range = np.arange(start_range, end_range, digit_size)
  sample_range_x = np.round(grid_x, 1)
  sample_range_y = np.round(grid_y, 1)
  plt.xticks(pixel_range, sample_range_x)
  plt.yticks(pixel_range, sample_range_y)
  plt.xlabel("z[0]")
  plt.ylabel("z[1]")
  plt.imshow(figure, cmap="Greys_r")
  plt.show()

plot_latent(encoder, decoder)

# %% [markdown]
# ## Display how the latent space clusters different digit classes

# %%
def plot_label_clusters(encoder, decoder, data, labels):
  """display a 2D plot of the digit classes in the latent space.

  Args:
    encoder: encoder neural network
    decoder: decoder neural network

  Returns:
    plt.scatter
  """
  z_mean, _, _ = encoder.predict(data)
  plt.figure(figsize=(12, 10))
  plt.scatter(z_mean[:, 0], z_mean[:, 1], c=labels)
  plt.colorbar()
  plt.xlabel("z[0]")
  plt.ylabel("z[1]")
  plt.show()

(x_train, y_train), _ = tf.keras.datasets.mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255

plot_label_clusters(encoder, decoder, x_train, y_train)
